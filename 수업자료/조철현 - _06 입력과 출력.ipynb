# %% [markdown]
# # 입력과 출력

# %% [markdown]
# ---

# %% [markdown]
# ## 표준 입출력(Standard Input/Output)

# %% [markdown]
# ### 표준 입력 함수

# %%
name = input("이름 : ")
print(name)
# Out:
# 이름 : 철현초이
# 철현초이

# %% [markdown]
# #### [Lab] 섭씨 온도를 화씨 온도로 변환
#
# * 섭씨 온도를 화씨 온도로 변환하는 공식: $F = (C * 1.8) + 32$

# %%
celsius = float(input("섭씨 온도 : "))
fahrenheit = (celsius * 1.8) + 32
print("화씨 온도 : ",fahrenheit)
# Out:
# 섭씨 온도 : 28
# 화씨 온도 :  82.4

# %% [markdown]
# #### [Lab] 구구단 중의 하나의 단을 입력받아 계산
#
# * 출력할 단을 입력
# * 해당 단의 계산 결과 출력

# %%
i = int(input("출력할 단 :"))
for j in range(1,10) :
  print("{0} x {1} = {2}".format(i,j,i*j))
# Out:
# 출력할 단 :2
# 2 x 1 = 2
# 2 x 2 = 4
# 2 x 3 = 6
# 2 x 4 = 8
# 2 x 5 = 10
# 2 x 6 = 12
# 2 x 7 = 14
# 2 x 8 = 16
# 2 x 9 = 18

# %% [markdown]
# ### 표준 출력 함수

# %%
print("Hello Python")
print("안녕 파이썬")
print(7)
print(3.14)
print([1,2,3])

print("Hello","Python",sep = "---")
print(1,2,3)
print(1, end=' ')
print(2, end=' ')
print(3, end=' ')
# Out:
# Hello Python
# 안녕 파이썬
# 7
# 3.14
# [1, 2, 3]
# Hello---Python
# 1 2 3
# 1 2 3

# %% [markdown]
# #### [Lab] 구구단 출력
#
# * `print()` 함수를 사용하여 각 단마다 횡으로 출력

# %%
for i in range(2,10):
  for j in range(1,10):
    print("{0} x {1} = {2}".format(i,j,i*j), end="\t")
# Out:
# 2 x 1 = 2	2 x 2 = 4	2 x 3 = 6	2 x 4 = 8	2 x 5 = 10	2 x 6 = 12	2 x 7 = 14	2 x 8 = 16	2 x 9 = 18	3 x 1 = 3	3 x 2 = 6	3 x 3 = 9	3 x 4 = 12	3 x 5 = 15	3 x 6 = 18	3 x 7 = 21	3 x 8 = 24	3 x 9 = 27	4 x 1 = 4	4 x 2 = 8	4 x 3 = 12	4 x 4 = 16	4 x 5 = 20	4 x 6 = 24	4 x 7 = 28	4 x 8 = 32	4 x 9 = 36	5 x 1 = 5	5 x 2 = 10	5 x 3 = 15	5 x 4 = 20	5 x 5 = 25	5 x 6 = 30	5 x 7 = 35	5 x 8 = 40	5 x 9 = 45	6 x 1 = 6	6 x 2 = 12	6 x 3 = 18	6 x 4 = 24	6 x 5 = 30	6 x 6 = 36	6 x 7 = 42	6 x 8 = 48	6 x 9 = 54	7 x 1 = 7	7 x 2 = 14	7 x 3 = 21	7 x 4 = 28	7 x 5 = 35	7 x 6 = 42	7 x 7 = 49	7 x 8 = 56	7 x 9 = 63	8 x 1 = 8	8 x 2 = 16	8 x 3 = 24	8 x 4 = 32	8 x 5 = 40	8 x 6 = 48	8 x 7 = 56	8 x 8 = 64	8 x 9 = 72	9 x 1 = 9	9 x 2 = 18	9 x 3 = 27	9 x 4 = 36	9 x 5 = 45	9 x 6 = 54	9 x 7 = 63	9 x 8 = 72	9 x 9 = 81

# %% [markdown]
# ---

# %% [markdown]
# ## 파일 입출력(File Input/Output)

# %% [markdown]
# ### 파일 입출력 과정
#
# * 파일의 입출력 과정은 단계를 가짐
# * 파일을 열고, 파일을 읽거나 쓰고, 파일을 닫는 순서

# %% [markdown]
# ### 파일 열기/닫기
#
# * file.txt 파일을 생성하고, 열고 닫기

# %%
f = open("file.txt",'w')
f = open("file.txt",'r')
f.close()

# %%
# !ls file.txt
# Out:
# file.txt

# %% [markdown]
# ### 파일 모드(File Mode)

# %% [markdown]
# ### 텍스트 파일 쓰기

# %% [markdown]
# #### write()
#
# * `write()`를 이용하여 파일에 쓰기

# %%
f = open("file.txt", 'w')
f.write("Hello Python")
f.close()

# %%
# !cat file.txt
# Out:
# Hello Python

# %% [markdown]
# #### writelines()
#
# * `writelines()`를 이용하여 list를 파일에 쓰기

# %%
list = ["One\n", "Two\n", "Three\n"]
f = open("file.txt",'w')
f.writelines(list)
f.close()

# %%
# !cat file.txt
# Out:
# One
# Two
# Three

# %% [markdown]
# #### 표준 입력 → 파일 쓰기
#
# * 표준 입력을 `input()` 함수를 통해 입력 받고, `write()` 함수를 통해 파일에 쓰기

# %%
txt = input("입력 : ")
f = open("file.txt",'w')
f.write(txt)
f.close()
# Out:
# 입력 : 초이초이

# %%
# !cat file.txt
# Out:
# 초이초이

# %%
text = [str(text + '\n') for text in input("여러 값 입력 :").split()]
f = open("file.txt",'w')
f.writelines(text)
f.close()
# Out:
# 여러 값 입력 :1 2 3

# %%
# !cat file.txt
# Out:
# 1
# 2
# 3

# %%
x = ""
text = ""
while x != 'q' :
  x = input("반복 입력")
  text += x + '\n'

f = open("file.txt",'w')
f.writelines(text)
f.close()
# Out:
# 반복 입력1
# 반복 입력
# 반복 입력2
# 반복 입력3
# 반복 입력
# 반복 입력q

# %%
# !cat file.txt
# Out:
# 1
#
# 2
# 3
#
# q

# %% [markdown]
# ### [Lab] 구구단 결과를 파일에 쓰기
#
# * 구구단 결과를 파일에 쓰기

# %%
f = open("dan.txt","w")
for i in range(2,10):
  for j in range(1,10):
    f.write("{0} x {1} = {2}\n".format(i,j,i*j))
  else :
    f.write("\n")
  
f.close()

# %%
# !cat dan.txt
# Out:
# 2 x 1 = 2
# 2 x 2 = 4
# 2 x 3 = 6
# 2 x 4 = 8
# 2 x 5 = 10
# 2 x 6 = 12
# 2 x 7 = 14
# 2 x 8 = 16
# 2 x 9 = 18
#
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27
#
# 4 x 1 = 4
# 4 x 2 = 8
# 4 x 3 = 12
# 4 x 4 = 16
# 4 x 5 = 20
# 4 x 6 = 24
# 4 x 7 = 28
# 4 x 8 = 32
# 4 x 9 = 36
#
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
#
# 6 x 1 = 6
# 6 x 2 = 12
# 6 x 3 = 18
# 6 x 4 = 24
# 6 x 5 = 30
# 6 x 6 = 36
# 6 x 7 = 42
# 6 x 8 = 48
# 6 x 9 = 54
#
# 7 x 1 = 7
# 7 x 2 = 14
# 7 x 3 = 21
# 7 x 4 = 28
# 7 x 5 = 35
# 7 x 6 = 42
# 7 x 7 = 49
# 7 x 8 = 56
# 7 x 9 = 63
#
# 8 x 1 = 8
# 8 x 2 = 16
# 8 x 3 = 24
# 8 x 4 = 32
# 8 x 5 = 40
# 8 x 6 = 48
# 8 x 7 = 56
# 8 x 8 = 64
# 8 x 9 = 72
#
# 9 x 1 = 9
# 9 x 2 = 18
# 9 x 3 = 27
# 9 x 4 = 36
# 9 x 5 = 45
# 9 x 6 = 54
# 9 x 7 = 63
# 9 x 8 = 72
# 9 x 9 = 81

# %% [markdown]
# ### 텍스트 파일 출력

# %% [markdown]
# * 텍스트 파일 예제

# %%
# !echo "동해물과 백두산이 마르고 닳도록" > anthem.txt
# !echo "하느님이 보우하사 우리나라 만세" >>anthem.txt

# %% [markdown]
# #### readline()
#
# * `readline()`를 이용하여 텍스트 파일을 라인 단위로 읽고 화면에 출력

# %%
f = open("anthem.txt",'r')
while True:
  line = f.readline()
  if not line: break
  print(line)

f.close()
# Out:
# 동해물과 백두산이 마르고 닳도록
#
# 하느님이 보우하사 우리나라 만세

# %% [markdown]
# #### readlines()
#
# * `readlines()`를 이용하여 텍스트 파일의 여러 라인을 읽고 화면에 출력

# %%
f = open("anthem.txt",'r')
lines = f.readlines()
print(lines)
f.close()
# Out:
# ['동해물과 백두산이 마르고 닳도록\n', '하느님이 보우하사 우리나라 만세\n']

# %% [markdown]
# #### read()
#
# * `read()`를 이용하여 텍스트 파일을 읽고 화면에 출력

# %%
f = open("anthem.txt",'r')
data = f.read()
print(data)
f.close()
# Out:
# 동해물과 백두산이 마르고 닳도록
# 하느님이 보우하사 우리나라 만세

# %% [markdown]
# #### tell()
#
# * 파일 포인터 위치 변경

# %%
f = open("anthem.txt", 'r')
while True:
  print(f.tell())
  line = f.readline()
  if not line: break
  print(line)

f.close()
# Out:
# 0
# 동해물과 백두산이 마르고 닳도록
#
# 46
# 하느님이 보우하사 우리나라 만세
#
# 92

# %% [markdown]
# #### seek()
#
# * 파일 포인터 위치 이동

# %%
f = open("anthem.txt", 'r')
f.seek(46)
line = f.readline()
print(line)
f.seek(0)
line = f.readline()
print(line)
f.close()
# Out:
# 하느님이 보우하사 우리나라 만세
#
# 동해물과 백두산이 마르고 닳도록

# %% [markdown]
# ### with 문
#
# * 항상 파일을 `open()` 함수로 열고, `close()` 함수로 닫아야 하는 일을 자동으로 처리
# * with문을 이용하면 with 블록 내에서 파일을 열고 벗어나면 파일을 닫음

# %%
f = open("file.txt",'w')
f.write("Hello Python")
f.close()

# %%
with open("file.txt",'w') as f:
  f.write("hello python")

# %% [markdown]
# ### [Lab] 표준 입력으로 받은 내용을 파일로 쓰기
#
# * 사용자로부터 표준 입력 받음
# * 받은 내용을 계속 파일 쓰기

# %%
f = open("file.txt", "w")
line = ""
while True :
  line = input()
  if not line: break
  f.writelines(line + '\n')

f.close()
# Out:
# 동해물과 백두산이 마르고 닳도록
# 하느님이 보우하사 우리나라 만세

# %%
# !cat file.txt
# Out:
# 동해물과 백두산이 마르고 닳도록
# 하느님이 보우하사 우리나라 만세

# %% [markdown]
# * 이진 파일(이미지) 예제

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-d36c64d7-e675-478e-a1f2-28694137ab50" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d36c64d7-e675-478e-a1f2-28694137ab50">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 골든타임_통장사본.jpg to 골든타임_통장사본.jpg
# {'골든타임_통장사본.jpg': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x00`\x00`\x00\x00\xff\xe1\x10\xecExif\x00\x00MM\x00*\x00\x00\x00\x08\x00\x04\x01;\x00\x02\x00\x00\x00\x13\x00\x00\x08J\x87i\x00\x04\x00\x00\x00\x01\x00\x00\x08^\x9c\x9d\x00\x01\x00\x00\x00\x0e\x00\x00\x10\xd6\xea\x1c\x00\x07\x00\x00\x08\x0c\x00\x00\x00>\x ...

# %%
# !ls
# Out:
# anthem.txt  dan.txt  file.txt  골든타임_통장사본.jpg  sample_data

# %% [markdown]
# ### 이진 파일 복사
#
# * 하나의 이진 파일을 읽어서 다른 이진 파일로 쓰기 (복사)

# %%
input = open("골든타임_통장사본.jpg","rb")
output = open("골든타임_통장사본_copy.jpg","wb")
while True:
  fp = input.read(1)
  if not fp : break
  output.write(fp)

input.close()
output.close()

# %%
# !ls
# Out:
# anthem.txt		    dan.txt   골든타임_통장사본.jpg
# 골든타임_통장사본_copy.jpg  file.txt  sample_data

# %% [markdown]
# ## 디렉토리 및 파일 처리

# %% [markdown]
# ### 디렉토리 생성
#
# * 디렉토리와 파일을 다루는 다양한 함수를 제공하는 shutil와 os 라이브러리
# * `mkdir()`: 디렉토리 생성

# %%
import os
import shutil
os.mkdir('test')
os.mkdir('test/1')
os.mkdir('test/2')
os.mkdir('test/3')

# %%
# !ls test

# %% [markdown]
# ### 디렉토리 및 파일 복사
#
# * `shutil.copy()`: 파일 복사
# * `shutil.copytree()`: 디렉토리 전체 복사

# %%
import shutil
shutil.copy("골든타임_통장사본.jpg", "골든타임_통장사본_copy2.jpg")
# Out:
# '골든타임_통장사본_copy2.jpg'

# %%
# !ls
# Out:
# anthem.txt		     dan.txt		    sample_data
# 골든타임_통장사본_copy2.jpg  file.txt		    test
# 골든타임_통장사본_copy.jpg   골든타임_통장사본.jpg

# %%
import shutil
shutil.copytree('test', 'test2')
# Out:
# 'test2'

# %%
# !ls
# Out:
# anthem.txt		     dan.txt		    sample_data
# 골든타임_통장사본_copy2.jpg  file.txt		    test
# 골든타임_통장사본_copy.jpg   골든타임_통장사본.jpg  test2

# %%
# !ls test2

# %% [markdown]
# ### 디렉토리 및 파일 확인
#
# * `isdir()`: 디렉토리 존재 확인
# * `isfile()`: 파일 존재 확인
# * `exists()`: 디렉토리/파일 존재 확인

# %%
import os.path
print(os.path.isdir('test'))
print(os.path.isdir('test/1'))
print(os.path.isdir('test/4'))
print(os.path.isfile('골든타임_통장사본.jpg'))
print(os.path.isfile('골든타임_통장사본_copy2.jpg'))
# Out:
# True
# True
# False
# True
# True

# %% [markdown]
# ### 디렉토리 목록 보기
#
# * `os.walk()`: 디렉토리 목록 보기

# %%
import os
for dir_name, dir_list, file_names in os.walk('./') :
  for file_name in file_names:
    print(os.path.join(dir_name, file_name))
# Out:
# ./file.txt
# ./골든타임_통장사본_copy2.jpg
# ./anthem.txt
# ./골든타임_통장사본.jpg
# ./dan.txt
# ./골든타임_통장사본_copy.jpg
# ./.config/gce
# ./.config/.last_opt_in_prompt.yaml
# ./.config/.last_update_check.json
# ./.config/config_sentinel
# ./.config/active_config
# ./.config/.last_survey_prompt.yaml
# ./.config/.metricsUUID
# ./.config/configurations/config_default
# ./.config/logs/2020.07.30/16.29.12.069758.log
# ./.config/logs/2020.07.30/16.30.04.899171.log
# ./.config/logs/2020.07.30/16.29.49.434074.log
# ./.config/logs/2020.07.30/16.30.04.254570.log
# ./.config/logs/2020.07.30/16.29.44.119840.log
# ./.config/logs/2020.07.30/16.29.30.511119.log
# ./sample_data/README.md
# ./sample_data/anscombe.json
# ./sample_data/mnist_test.csv
# ./sample_data/california_housing_test.csv
# ./sample_data/mnist_train_small.csv
# ./sample_data/california_housing_train.csv

# %% [markdown]
# ### 디렉토리 및 파일 삭제
#
# * `os.remove()`: 파일 삭제
# * `shutil.rmtree()`: 디렉토리 안에 모든 파일/디렉토리 삭제

# %%
import os
os.remove('골든타임_통장사본_copy.jpg')
os.remove('골든타임_통장사본_copy2.jpg')

# %%
# !ls
# Out:
# anthem.txt  dan.txt  file.txt  골든타임_통장사본.jpg  sample_data  test  test2

# %%
import shutil
shutil.rmtree('test')
shutil.rmtree('test2')

# %%
# !ls
# Out:
# anthem.txt  dan.txt  file.txt  골든타임_통장사본.jpg  sample_data

# %% [markdown]
# ### 파일 크기
#
# * `os.path.getsize()`: 파일의 크기를 바이트 단위로 출력

# %%
import os.path
print(os.path.getsize('골든타임_통장사본.jpg'))
# Out:
# 51468

# %% [markdown]
# ### 파일 압축

# %%
import zipfile
comp = zipfile.ZipFile('New.zip','w')
comp.write('골든타임_통장사본.jpg')
comp.close()

# %%
# !ls
# Out:
# anthem.txt  dan.txt  file.txt  골든타임_통장사본.jpg  New.zip  sample_data

# %%
decomp = zipfile.ZipFile("New.zip",'r')
decomp.extractall('New')
decomp.close()

# %%
# !ls
# Out:
# anthem.txt  dan.txt  file.txt  골든타임_통장사본.jpg  New.zip  sample_data
